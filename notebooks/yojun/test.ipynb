# %%
import pandas as pd

# %%
df = pd.read_csv("C:\POTENUP\MumulMumul\storage\expected_questions.csv", index_col = 0)

# %%
df.head()
# Out:
#                                                       질문 난이도
# 질문 번호
# 1      Python에서 **uv**를 사용하는 것이 pip install 명령어를 직접 사...  초보
# 2      Pandas **DataFrame**에서 결측치를 확인하고 처리하는 기본적인 방법을...  초보
# 3      머신러닝에서 **'과적합(Overfitting)'**이란 무엇이며, 이를 방지하기 ...  초보
# 4      **Object Detection(객체 탐지)**과 **Image Classific...  초보
# 5      **합성곱 신경망(CNN)**에서 풀링(Pooling) 계층을 사용하는 주요 목적은...  초보

# %%
result = df.iloc[1:51]

# %%
for i in result:
    [print(i)]
# Out:
# 질문
# 난이도

# %%
df1 = pd.read_csv("C:\POTENUP\MumulMumul\storage\expected_questions.csv", index_col = 0)
df2 = pd.read_csv("C:\POTENUP\MumulMumul\storage\expected_score.csv", index_col=0)

# %%
df2
# Out:
#        점수                                                 이유
# 질문 번호
# 1      85  정확한 내용이지만 약간 장황하고 핵심 포인트(uv=속도/효율성/lock-free d...
# 2      95               결측치 확인/처리 방법이 정확히 기술되었고 초보자 관점에서 완전함
# 3      88  과적합 정의는 정확하나 '데이터 수 늘리기' 이외의 기본적 방법(정규화·dropou...
# 4      95                    객체 탐지 vs 분류의 차이를 예시 포함해 정확하게 설명
# 5      94           CNN 풀링 목적을 정확히 설명. 다만 예시가 조금 더 간결할 수 있었음
# 6      95                     비선형성의 필요성을 정확하게 설명함. 논리적 흐름 좋음
# 7      95                             IoU 정의와 임계값 활용 설명이 완벽함
# 8      96             Prophet 구성요소·장점 모두 정확. 실무 관점에서도 높은 정확성
# 9      95              그래디언트와 가중치 업데이트 연결 설명 정확. 핵심 요소 누락 없음
# 10     94               과정은 모두 맞음. 단, uv venv의 경로 예시가 약간 장황함
# 11     95               연속형 vs 범주형 시각화 방법을 적절한 이유와 함께 정확히 설명
# 12     94  K-means의 작동 원리 정확함. 단, '초기 centroid 랜덤 문제' 등 부...
# 13     93  Stride의 개념은 정확하지만 stride가 출력 크기에 미치는 영향 식이 있었으...
# 14     95          Precision/Recall 정의·Trade-off 설명 정확하고 구조적
# ...

# %%
df2.drop("질문 번호", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df2.drop("질문 번호", axis=1)
#
# File c:\POTENUP\MumulMumul\.venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

df_13_axis1 = pd.concat([df1, df2], axis=1)

# %%
df_13_axis1
df_13_axis1.to_csv("C:\POTENUP\MumulMumul\storage\expected_all.csv")
